# %%
# !pip install urlextract

# %%
import io, os, requests
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score
from catboost import CatBoostRegressor
from urlextract import URLExtract
from tqdm.auto import tqdm
sns.set()

# %%
train_data = pd.read_csv('/kaggle/input/behaviour-simulation-train/behaviour_simulation_train.csv')
test_data = pd.read_csv('/kaggle/input/behaviour-simulation-test/behaviour_simulation_test_company.csv')

# %%
# X = train_data.loc[:,['username', 'inferred company']]
# y = train_data['likes']

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, shuffle = True, random_state = 42)

# %%
# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# %%
# model = CatBoostRegressor(n_estimators = 1000,
#                         learning_rate = 0.1,
#                         depth = 7,
#                         loss_function = 'RMSE',
#                         random_seed = 42,
#                         verbose = 100,)

# %%
# model.fit(X_train, y_train_log, cat_features = [0,1])
# y_pred = model.predict(X_test)

# %%
extractor = URLExtract()

# %%
folder_path = '/kaggle/working/train_images'
os.makedirs(folder_path, exist_ok = True)

# %%
# for i in range(300000):
#     urls = extractor.find_urls(train_data['media'][i])
#     response = requests.get(urls[0])
#     if response.status_code != 200:
#         cnt+=1
#     else:
#         with open(f"{file_path}/{i}.jpg", 'wb') as file:
#             file.write(response.content)

# %%
# failed_idx = []

# %%
# %%time
# urls = extractor.find_urls(train_data['media'][0])
# # response = requests.get(urls[0])

# %%
# %%time
# response = requests.get(urls[0])

# %%
# %%time
# img_bytes = io.BytesIO(response.content)
# img = Image.open(img_bytes)
# img_filename = os.path.join(folder_path, f'{0}.jpg')
# img.save(img_filename)

# %%
for i in tqdm(range(200000, 250000)):
    try:
        urls = extractor.find_urls(train_data['media'][i])
        response = requests.get(urls[0])

        if response.status_code == 200:
            img_bytes = io.BytesIO(response.content)
            img = Image.open(img_bytes)
            img_filename = os.path.join(folder_path, f'{i}.jpg')
            img.save(img_filename)
#             print(f"Image {i+1} downloaded and saved as {img_filename}")
        else:
#             failed_idx.append(i)
            print(f"Failed to download image {i}. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while downloading image {i}: {e}")
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# An error occurred while downloading image 200004: cannot write mode RGBA as JPEG
# Failed to download image 200009. Status code: 404
# Failed to download image 200040. Status code: 404
# Failed to download image 200048. Status code: 404
# Failed to download image 200091. Status code: 404
# Failed to download image 200097. Status code: 404
# Failed to download image 200106. Status code: 404
# An error occurred while downloading image 200114: cannot write mode P as JPEG
# Failed to download image 200124. Status code: 404
# Failed to download image 200131. Status code: 404
# An error occurred while downloading image 200184: cannot write mode P as JPEG
# An error occurred while downloading image 200188: cannot write mode RGBA as JPEG
# Failed to download image 200224. Status code: 404
# Failed to download image 200241. Status code: 404
# An error occurred while downloading image 200245: cannot write mode RGBA as JPEG
# ...
